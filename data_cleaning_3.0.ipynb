# %% [markdown]
# Data wrangling to-do-list:
# <li> (1) Qualtrics was set up with three randomized series for the Snowy Picture Task. This means that an answer for a question may be found in 1 of 3 places in the dataset. Step 1 is to organize the dataset so that each question - regardless of in which series it appeared - is assigned to the same variable.
#     <li> (2) Create a dummy variable based on the 'submit page' data for either of manipulation pages on Qualtrics. This dummy variable is necessary to distinguish between the two experimental groups (emotional and reasoned).
#         <li> (3) return a  numerical variable that represents how many associations an individual case came up with for both tasks.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <li> Import the necessary libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <li> Import our data file. the variable that represents the data file will be called 'df' (= <b>D</b>ata<b>F</b>rame)

# %%
df = pd.read_csv(r'/Users/Michiel/Desktop/full_data.csv')

# %% [markdown]
# <li> Make sure that our object is indeed a Pandas dataframe.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <li> Get a snapshot overview of our dataframe to make sure everything imported correctly.

# %%
df
# Out:
#                    ResponseId  \
# 0                 Response ID
# 1    {"ImportId":"_recordId"}
# 2           R_22PI0Pj2CyHOohf
# 3           R_2B5v8VLs5iZUyo1
# 4           R_Zl4GLjuRDhOZAv7
# ..                        ...
# 133         R_3MxO5UY4uCBtcPy
# 134         R_vJNolB1WjTKrEVr
# 135         R_3iVkkks0z2a15gP
# 136         R_2s7w3b88tzDM6j8
# 137         R_3HC8Yj3zxcvpDVz
#
#                                           RecordedDate  \
# 0                                        Recorded Date
# 1    {"ImportId":"recordedDate","timeZone":"Europe/...
# 2                                  2020-04-21 11:35:02
# 3                                  2020-04-21 12:43:27
# 4                                  2020-04-21 13:20:58
# ..                                                 ...
# 133                                2020-05-06 00:00:37
# 134                                2020-05-06 11:13:57
# 135                                2020-05-06 11:27:08
# 136                                2020-05-06 12:16:08
# 137                                2020-05-06 14:23:39
#
#                     Progress               Emo_man_Page Submit  \
# 0                   Progress              Timing - Page Submit
# 1    {"ImportId":"progress"}  {"ImportId":"QID70_PAGE_SUBMIT"}
# 2                        100                               NaN
# 3                        100                            15.295
# 4                        100                            31.678
# ..                       ...                               ...
# 133                      100                               NaN
# 134                      100                               NaN
# 135                      100                            18.187
# 136                       54                              12.1
# 137                      100                               NaN
#
#                 Rea_man_1_Page Submit  \
# 0                Timing - Page Submit
# 1    {"ImportId":"QID68_PAGE_SUBMIT"}
# 2                                28.8
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 133                            10.998
# 134                            21.129
# 135                               NaN
# 136                               NaN
# 137                            96.623
#
#                                              SPT_S1_Q1  \
# 0    To what extent did you see a figure, object, o...
# 1                                 {"ImportId":"QID80"}
# 2                                                    2
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                  7
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              SPT_S1_Q2  \
# 0    To what extent did you see a figure, object, o...
# 1                                 {"ImportId":"QID84"}
# 2                                                    3
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                  6
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              SPT_S1_Q5  \
# 0    To what extent did you see a figure, object, o...
# 1                                 {"ImportId":"QID94"}
# 2                                                    2
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                  5
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                              SPT_S1_Q8  \
# 0    To what extent did you see a figure, object, o...
# 1                                {"ImportId":"QID104"}
# 2                                                    1
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                  6
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                             SPT_S1_Q10  ...  \
# 0    To what extent did you see a figure, object, o...  ...
# 1                                {"ImportId":"QID111"}  ...
# 2                                                    5  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 133                                                NaN  ...
# 134                                                  5  ...
# 135                                                NaN  ...
# 136                                                NaN  ...
# 137                                                NaN  ...
#
#                                       AUT_S2_QBrick_12  \
# 0    Come up with as many uses as you can for a bri...
# 1                             {"ImportId":"QID310_12"}
# 2                                                als e
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                       AUT_S2_QBrick_11  \
# 0    Come up with as many uses as you can for a bri...
# 1                             {"ImportId":"QID310_11"}
# 2                            in plantenbak als vulling
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                       AUT_S2_QBrick_10  \
# 0    Come up with as many uses as you can for a bri...
# 1                             {"ImportId":"QID310_10"}
# 2                                         kapot gooien
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                        AUT_S2_QBrick_9  \
# 0    Come up with as many uses as you can for a bri...
# 1                              {"ImportId":"QID310_9"}
# 2                          om hete dingen op te zetten
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                        AUT_S2_QBrick_8  \
# 0    Come up with as many uses as you can for a bri...
# 1                              {"ImportId":"QID310_8"}
# 2                                          onderzetter
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                        AUT_S2_QBrick_4  \
# 0    Come up with as many uses as you can for a bri...
# 1                              {"ImportId":"QID310_4"}
# 2                       bbq  maken met meerdere stenen
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                   Ter versteviging
# 136                                                NaN
# 137                                   Boeken standaard
#
#                                        AUT_S2_QBrick_5  \
# 0    Come up with as many uses as you can for a bri...
# 1                              {"ImportId":"QID310_5"}
# 2                                             tafeltje
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                              Te vervormen tot iets
# 136                                                NaN
# 137                                                Keg
#
#                                        AUT_S2_QBrick_3  \
# 0    Come up with as many uses as you can for a bri...
# 1                              {"ImportId":"QID310_3"}
# 2                                       raam in gooien
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                               Bloemen in te steken
# 136                                                NaN
# 137                                            Gewicht
#
#                                        AUT_S2_QBrick_2  \
# 0    Come up with as many uses as you can for a bri...
# 1                              {"ImportId":"QID310_2"}
# 2                                             stapelen
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                  Remmend materiaal
# 136                                                NaN
# 137                                  Verzwaringsobject
#
#                                        AUT_S2_QBrick_1
# 0    Come up with as many uses as you can for a bri...
# 1                              {"ImportId":"QID310_1"}
# 2                                               bouwen
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                             Maken van kerststukjes
# 136                                                NaN
# 137                                           Opstapje
#
# [138 rows x 98 columns]

# %% [markdown]
# Index 0 and 1 are redundant. They provide equivelant information to our header. The rows represented by these index numbers will be dropped from our dataframe.

# %%
df = df.drop(df.index[[0, 1]])

# %% [markdown]
# <li> View how many variables are in the data (represented by columns in the data frame)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 2 to 137
# Data columns (total 98 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ResponseId             136 non-null    object
#  1   RecordedDate           136 non-null    object
#  2   Progress               136 non-null    object
#  3   Emo_man_Page Submit    65 non-null     object
#  4   Rea_man_1_Page Submit  71 non-null     object
#  5   SPT_S1_Q1              47 non-null     object
#  6   SPT_S1_Q2              47 non-null     object
#  7   SPT_S1_Q5              47 non-null     object
#  8   SPT_S1_Q8              47 non-null     object
#  9   SPT_S1_Q10             47 non-null     object
#  10  SPT_S1_Q12             47 non-null     object
#  11  SPT_S2_Q12             44 non-null     object
#  12  SPT_S2_Q2              44 non-null     object
#  13  SPT_S2_Q10             44 non-null     object
#  14  SPT_S2_Q8              44 non-null     object
#  15  SPT_S2_Q5              44 non-null     object
#  16  SPT_S2_Q1              44 non-null     object
#  17  SPT_S3_Q5              44 non-null     object
#  18  SPT_S3_Q12             44 non-null     object
#  19  SPT_S3_Q1              44 non-null     object
#  20  SPT_S3_Q2              44 non-null     object
#  21  SPT_S3_Q8              44 non-null     object
#  22  SPT_S3_Q10             44 non-null     object
#  23  Control_1_1            127 non-null    object
#  24  Control_1_2            127 non-null    object
#  25  Control_1_3            127 non-null    object
#  26  Control_2              127 non-null    object
#  27  Control_3              127 non-null    object
#  28  Control_5              127 non-null    object
#  29  Control_6              127 non-null    object
#  30  Control_7              23 non-null     object
#  31  MANC_EMO_1             59 non-null     object
#  32  MANC_REA_1             66 non-null     object
#  33  Duration (in seconds)  136 non-null    object
#  34  LocationLatitude       125 non-null    object
#  35  LocationLongitude      125 non-null    object
#  36  StartDate              136 non-null    object
#  37  Control_4              62 non-null     object
#  38  AUT_S1_QBrick_1        62 non-null     object
#  39  AUT_S1_QBrick_5        49 non-null     object
#  40  AUT_S1_QBrick_4        58 non-null     object
#  41  AUT_S1_QBrick_3        59 non-null     object
#  42  AUT_S1_QBrick_2        61 non-null     object
#  43  AUT_S1_QBrick_8        40 non-null     object
#  44  AUT_S1_QBrick_12       18 non-null     object
#  45  AUT_S1_QBrick_11       23 non-null     object
#  46  AUT_S1_QBrick_10       30 non-null     object
#  47  AUT_S1_QBrick_9        36 non-null     object
#  48  AUT_S1_QBrick_17       5 non-null      object
#  49  AUT_S1_QBrick_16       7 non-null      object
#  50  AUT_S1_QBrick_15       8 non-null      object
#  51  AUT_S1_QBrick_14       12 non-null     object
#  52  AUT_S1_QBrick_13       15 non-null     object
#  53  AUT_S1_QPAC_17         2 non-null      object
#  54  AUT_S1_QPAC_16         2 non-null      object
#  55  AUT_S1_QPAC_15         3 non-null      object
#  56  AUT_S1_QPAC_14         4 non-null      object
#  57  AUT_S1_QPAC_13         6 non-null      object
#  58  AUT_S1_QPAC_12         12 non-null     object
#  59  AUT_S1_QPAC_11         15 non-null     object
#  60  AUT_S1_QPAC_10         18 non-null     object
#  61  AUT_S1_QPAC_9          30 non-null     object
#  62  AUT_S1_QPAC_8          34 non-null     object
#  63  AUT_S1_QPAC_5          41 non-null     object
#  64  AUT_S1_QPAC_4          50 non-null     object
#  65  AUT_S1_QPAC_3          55 non-null     object
#  66  AUT_S1_QPAC_2          60 non-null     object
#  67  AUT_S1_QPAC_1          62 non-null     object
#  68  AUT_S2_QPac_8          32 non-null     object
#  69  AUT_S2_QPac_5          45 non-null     object
#  70  AUT_S2_QPac_4          50 non-null     object
#  71  AUT_S2_QPac_3          60 non-null     object
#  72  AUT_S2_QPac_2          64 non-null     object
#  73  AUT_S2_QPac_1          65 non-null     object
#  74  AUT_S2_QPac_9          26 non-null     object
#  75  AUT_S2_QPac_10         15 non-null     object
#  76  AUT_S2_QPac_17         0 non-null      object
#  77  AUT_S2_QPac_16         0 non-null      object
#  78  AUT_S2_QPac_15         0 non-null      object
#  79  AUT_S2_QPac_14         0 non-null      object
#  80  AUT_S2_QPac_13         1 non-null      object
#  81  AUT_S2_QPac_12         3 non-null      object
#  82  AUT_S2_QPac_11         6 non-null      object
#  83  AUT_S2_QBrick_17       0 non-null      object
#  84  AUT_S2_QBrick_16       1 non-null      object
#  85  AUT_S2_QBrick_15       1 non-null      object
#  86  AUT_S2_QBrick_14       2 non-null      object
#  87  AUT_S2_QBrick_13       5 non-null      object
#  88  AUT_S2_QBrick_12       8 non-null      object
#  89  AUT_S2_QBrick_11       11 non-null     object
#  90  AUT_S2_QBrick_10       15 non-null     object
#  91  AUT_S2_QBrick_9        27 non-null     object
#  92  AUT_S2_QBrick_8        38 non-null     object
#  93  AUT_S2_QBrick_4        55 non-null     object
#  94  AUT_S2_QBrick_5        47 non-null     object
#  95  AUT_S2_QBrick_3        62 non-null     object
#  96  AUT_S2_QBrick_2        64 non-null     object
#  97  AUT_S2_QBrick_1        65 non-null     object
# dtypes: object(98)
# memory usage: 105.2+ KB

# %% [markdown]
# All of the datatypes in the dataframe are objects. This implies that everything (including the numbers) are represented as string in the dataframe. As a consequence, any mathematical calculations are not possible unless we convert them to integers or floats.
#
# <li> convert objects to floats.

# %%
df[df.columns[5:26]] = df[df.columns[5:26]].astype(float)
df[df.columns[2]] = df[df.columns[2]].astype(float)
df[df.columns[27]] = df[df.columns[27]].astype(float)
df[df.columns[31:33]] = df[df.columns[31:33]].astype(float)
df['Duration (in seconds)'] = df['Duration (in seconds)'].astype(float)

# %% [markdown]
# <li> Drop all incompleted surveys.
#     <li> View how many cases are left afterwards.

# %%
df = df.loc[df['Progress'] == 100]
len(df)
# Out:
# 125

# %% [markdown]
# <li> 'merge' all SPT-task series variables into one.
# <li> Turn all NaN (missing values) into a float value 0 in order to be able to succesfully add them.

# %%
df['SPT_AG_Q1'] = df.fillna(0)['SPT_S1_Q1'] + df.fillna(0)['SPT_S2_Q1'] + df.fillna(0)['SPT_S3_Q1']

# %%
df['SPT_AG_Q2'] = df.fillna(0)['SPT_S1_Q2'] + df.fillna(0)['SPT_S2_Q2'] + df.fillna(0)['SPT_S3_Q2']

# %%
df['SPT_AG_Q5'] = df.fillna(0)['SPT_S1_Q5'] + df.fillna(0)['SPT_S2_Q5'] + df.fillna(0)['SPT_S3_Q5']

# %%
df['SPT_AG_Q8'] = df.fillna(0)['SPT_S1_Q8'] + df.fillna(0)['SPT_S2_Q8'] + df.fillna(0)['SPT_S3_Q8']

# %%
df['SPT_AG_Q10'] = df.fillna(0)['SPT_S1_Q10'] + df.fillna(0)['SPT_S2_Q10'] + df.fillna(0)['SPT_S3_Q10']

# %%
df['SPT_AG_Q12'] = df.fillna(0)['SPT_S1_Q12'] + df.fillna(0)['SPT_S2_Q12'] + df.fillna(0)['SPT_S3_Q12']

# %% [markdown]
# <li> Create a total score per respondent. We'll need to add all of the columns together.

# %%
df['SPT_TOTAL'] = df['SPT_AG_Q1'] + df['SPT_AG_Q2'] + df['SPT_AG_Q5'] + df['SPT_AG_Q8'] + df['SPT_AG_Q10'] + df['SPT_AG_Q12']

# %% [markdown]
# The 'Emo_man_Page Submit' variable data to <b>create a dummy variable</b>.
# It can be programmed to display a 0/1 based on the fact that the emotions manipulation page has been displayed to the respondent.
#     <li> 1 = emotion manipulation
#         <li> 0 = reason manipulation

# %%
df['Emo_man_Page Submit'] = df.fillna(1)['Emo_man_Page Submit']

df['Emo_man_Page Submit'] = pd.get_dummies(df['Emo_man_Page Submit'])

df['Emo_man_Page Submit'] = df['Emo_man_Page Submit'].astype(int)

# %% [markdown]
# The association task is set up in a way that each seperate answer-slot (15 slots in total per task) represents a value.
# This has to be turned into a total, numerical score.

# %%
# seperate the AUT-task variables from the data frame.
# simultaneously tell python to turn missing values into '0' and fields with text into '1'
new_data = df[df.columns[38:98]].notnull().astype('int')

# create a new variable / column to represent the sum of all columns per row 
new_data['TOTAL'] = new_data.sum(axis=1)

# concatenate new_data with our original dataframe 'df' 
concat_data = pd.concat([df, new_data['TOTAL']], axis=1)

# write csv file in order to be able to use it in SPSS
concat_data.to_csv('full_data_clean.csv', header=True, index=True)
